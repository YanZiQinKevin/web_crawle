# %%
import pandas
exchange=pandas.read_html('http://www.boc.cn/sourcedb/whpj/')
len(exchange)
exchange[1]
# Out:
#          0       1       2       3        4       5           6         7
# 0     货币名称   现汇买入价   现钞买入价   现汇卖出价    现钞卖出价   中行折算价        发布日期      发布时间
# 1   阿联酋迪拉姆     NaN  166.66     NaN   178.74  172.69  2018-02-21  14:12:59
# 2    澳大利亚元  496.72  481.28  500.37   501.46  498.61  2018-02-21  14:12:59
# 3    巴西里亚尔     NaN  187.07     NaN    204.6  192.37  2018-02-21  14:12:59
# 4     加拿大元  499.47   483.7  503.15   504.25  503.81  2018-02-21  14:12:59
# 5     瑞士法郎  674.41   653.6  679.15   680.84  678.21  2018-02-21  14:12:59
# 6     丹麦克朗  104.58  101.35  105.42   105.63  105.15  2018-02-21  14:12:59
# 7       欧元  779.46  755.25  785.21   786.78  783.43  2018-02-21  14:12:59
# 8       英镑  884.04  856.57  890.55    892.5  880.68  2018-02-21  14:12:59
# 9       港币   80.91   80.27   81.23    81.23   81.09  2018-02-21  14:12:59
# 10    印尼卢比     NaN   0.045     NaN   0.0482  0.0464  2018-02-21  14:12:59
# 11    印度卢比     NaN  9.1985     NaN  10.3727  9.8654  2018-02-21  14:12:59
# ...

# %%
currency=exchange[1]
currency=currency.loc[:, lambda currency: [0, 2,4,5]]
currency.to_excel('exchange.xlsx')
currency
# Out:
#          0       2        4       5
# 0     货币名称   现钞买入价    现钞卖出价   中行折算价
# 1   阿联酋迪拉姆  166.66   178.74  172.69
# 2    澳大利亚元  481.28   501.46  498.61
# 3    巴西里亚尔  187.07    204.6  192.37
# 4     加拿大元   483.7   504.25  503.81
# 5     瑞士法郎   653.6   680.84  678.21
# 6     丹麦克朗  101.35   105.63  105.15
# 7       欧元  755.25   786.78  783.43
# 8       英镑  856.57    892.5  880.68
# 9       港币   80.27    81.23   81.09
# 10    印尼卢比   0.045   0.0482  0.0464
# 11    印度卢比  9.1985  10.3727  9.8654
# 12      日元  5.6861   5.9116   5.885
# 13     韩国元  0.5663   0.6132  0.5846
# 14     澳门元   76.02     81.5   78.72
# 15     林吉特     NaN      NaN  161.17
# 16    挪威克朗   77.96    81.25   80.59
# 17    新西兰元  449.42   472.71  461.62
# 18   菲律宾比索   11.75    12.79   12.17
# 19      卢布   10.47    11.67      11
# 20   沙特里亚尔  164.45   173.01  169.13
# 21    瑞典克朗   75.53    78.72   79.01
# 22    新加坡元  463.94   483.27  479.49
# 23     泰国铢   19.41    20.81   20.15
# 24   土耳其里拉  158.31   175.95  166.54
# ...
